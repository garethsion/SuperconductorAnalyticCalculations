# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import emproperties as emp
import inductance as inp

from scipy.constants import constants as sc

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set_context("poster")
sns.set_style("ticks",{"xtick.direction" : u"in",
                       "ytick.direction" : u"in"})
sns.set_palette(sns.color_palette("coolwarm", 4))

# %%
ind = inp.Inductance(a=1, b=2, d=50e-09, pen_depth=33.3e-09)

ind.a = 5e-06
ind.b = np.arange(0.1e-06,16e-06,0.05e-06)

L1 = ind.get_geometric_inductance()
L2 = ind.get_Lml_approximate1()
L3 = ind.get_Lml_approximate2()
# Out:
# /Users/garethjones/PythonScripts/SuperconductorAnalyticCalcs/Plot Notebooks/physicalproperties.py:53: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(1-self.k**2)
# /Users/garethjones/PythonScripts/SuperconductorAnalyticCalcs/Plot Notebooks/inductance.py:27: RuntimeWarning: invalid value encountered in log
#   Lml2 = ((np.pi*sc.mu_0)/4) / np.log((8*self._a)/(self._b-self._a))

# %%
plt.figure(figsize=(12,8))
plt.plot(ind.b/ind.a,L1/sc.mu_0,label="Exact")
plt.plot(ind.b/ind.a,L2/sc.mu_0,label="Approximate 1")
plt.plot(ind.b/ind.a,L3/sc.mu_0,label="Approximate 2")

plt.xlabel("b/a")
plt.ylabel("$L'_{m}/\mu_{0}$")

plt.legend()
plt.savefig('figs/ClemFig3_Lm_with_approxs.pdf',bbox_inches=None)
plt.show()
